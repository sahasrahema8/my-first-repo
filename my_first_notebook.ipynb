# %%
hardware and software are two main parts of a computer. hardware means the physical parts you can touch, like keyboard, while software means the programs that run on the computer, like windows. both work together to make the computer function.
